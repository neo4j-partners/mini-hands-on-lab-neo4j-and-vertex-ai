# %%
# %%capture
# %pip install kaggle

# %%
from typing import Iterable, Callable, Dict, Tuple
import pandas as pd
import numpy as np
from numpy.typing import ArrayLike
import data_utils as du
import os

# %%
REGION = os.getenv('us-central1')
shell_output = ! gcloud config list --format 'value(core.project)' 2>/dev/null
PROJECT_ID = shell_output[0]

STORAGE_BUCKET = 'neo4j-insurance-claim-tutorial-data'
os.environ["GCLOUD_PROJECT"] = PROJECT_ID

# %%
!~/.local/bin/kaggle datasets download -d rohitrox/healthcare-provider-fraud-detection-analysis -p data
# Out:
# healthcare-provider-fraud-detection-analysis.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !cd data && unzip -n '*.zip'
# Out:
# Archive:  healthcare-provider-fraud-detection-analysis.zip

# %%
provider_df = du.make_provider_df()
provider_df.to_csv('provider.csv', index=False)
provider_df
# Out:
#       provider potentialFraud  potentialFraudInd
# 0     PRV51001             No                  0
# 1     PRV51003            Yes                  1
# 2     PRV51004             No                  0
# 3     PRV51005            Yes                  1
# 4     PRV51007             No                  0
# ...        ...            ...                ...
# 5405  PRV57759             No                  0
# 5406  PRV57760             No                  0
# 5407  PRV57761             No                  0
# 5408  PRV57762             No                  0
# 5409  PRV57763             No                  0
#
# [5410 rows x 3 columns]

# %%
from google.cloud import storage

client = storage.Client()
bucket = client.bucket(STORAGE_BUCKET)
if not bucket.exists():
    bucket.create(location=REGION)

# %%
blob = bucket.blob('provider.csv')
blob.upload_from_filename('provider.csv')

# %%
claim_df = du.make_claim_df()
claim_df.to_csv('claim.csv', index=False)
claim_df
# Out:
#             beneID    claimID claimStartDt claimEndDt  provider  \
# 0        BENE11001   CLM46614   2009-04-12 2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31 2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17 2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14 2009-02-22  PRV52405
# 4        BENE11011  CLM144521   2009-01-18 2009-01-18  PRV52314
# ...            ...        ...          ...        ...       ...
# 558206  BENE159198  CLM510792   2009-08-06 2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29 2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24 2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18 2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17 2009-11-18  PRV53689
#
#         inscClaimAmtReimbursed attendingPhysician operatingPhysician  \
# 0                        26000          PHY390922                NaN
# 1                         5000          PHY318495          PHY318495
# 2                         5000          PHY372395                NaN
# 3                         5000          PHY369659          PHY392961
# 4                           50          PHY379398                NaN
# ...                        ...                ...                ...
# 558206                     800          PHY364188          PHY364188
# 558207                     400          PHY423019          PHY332284
# 558208                      60          PHY361063                NaN
# 558209                      70          PHY403198                NaN
# 558210                      80          PHY419379                NaN
#
#        otherPhysician admissionDt  ... chronicCondrheumatoidarthritis  \
# 0                 NaN  2009-04-12  ...                              1
# 1                 NaN  2009-08-31  ...                              1
# 2           PHY324689  2009-09-17  ...                              1
# 3           PHY349768  2009-02-14  ...                              1
# 4                 NaN         NaT  ...                              1
# ...               ...         ...  ...                            ...
# 558206      PHY385752         NaT  ...                              1
# 558207            NaN         NaT  ...                              1
# 558208            NaN         NaT  ...                              1
# 558209      PHY419379         NaT  ...                              1
# 558210      PHY419379         NaT  ...                              1
#
#         chronicCondstroke iPAnnualReimbursementAmt iPAnnualDeductibleAmt  \
# 0                       1                    36000                  3204
# 1                       1                    36000                  3204
# 2                       1                    36000                  3204
# 3                       1                     5000                  1068
# 4                       1                     5000                  1068
# ...                   ...                      ...                   ...
# 558206                  0                        0                     0
# 558207                  0                        0                     0
# 558208                  0                        0                     0
# 558209                  0                        0                     0
# 558210                  0                        0                     0
#
#        oPAnnualReimbursementAmt oPAnnualDeductibleAmt dobYear isDeceased  \
# 0                            60                    70    1943          0
# 1                            60                    70    1943          0
# 2                            60                    70    1943          0
# 3                           250                   320    1914          0
# 4                           250                   320    1914          0
# ...                         ...                   ...     ...        ...
# 558206                     5470                  1870    1952          0
# 558207                     5470                  1870    1952          0
# 558208                     5470                  1870    1952          0
# 558209                     5470                  1870    1952          0
# 558210                     5470                  1870    1952          0
#
#           maxDate approxAge
# 0      2009-12-01      67.0
# 1      2009-12-01      67.0
# 2      2009-12-01      67.0
# 3      2009-12-01      95.8
# 4      2009-12-01      95.8
# ...           ...       ...
# 558206 2009-12-01      57.7
# 558207 2009-12-01      57.7
# 558208 2009-12-01      57.7
# 558209 2009-12-01      57.7
# 558210 2009-12-01      57.7
#
# [558211 rows x 64 columns]

# %%
blob = bucket.blob('claim.csv')
blob.upload_from_filename('claim.csv')
